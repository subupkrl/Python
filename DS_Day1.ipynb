# %% [markdown]
# <a href="https://colab.research.google.com/github/subupkrl/Assignment/blob/master/DS_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 20
print (x)
# Out:
# 20

# %%
fname = 'Shubhechchha'
print ("My name is",fname)
# Out:
# My name is Shubhechchha

# %%
text = "This is a python course which is essential for Data Science"
print (text[5])
print (text[2:10])
print (text[:10])
print (text[10:])
print (text[:])
print (text[-1])
print (text[-10:-2])
# Out:
# i
# is is a
# This is a
# python course which is essential for Data Science
# This is a python course which is essential for Data Science
# e
# ta Scien

# %%
thislist = ["apple","banana","cherry"]
print (thislist[0][0])
print (thislist[0][0:3])
# Out:
# a
# app

# %%
student ={
    "fname":"Shyam",
    "lname":"Giri",
    "age":"25",
    "gender":"male"
}
print(student)
print(student["fname"])
# Out:
# {'fname': 'Shyam', 'lname': 'Giri', 'age': '25', 'gender': 'male'}
# Shyam

# %%
x = 20 % 3
print (x)
# Out:
# 2

# %%
num = 20
if num % 2 == 0:
    print ("even")
else:
    print("odd")
# Out:
# even

# %%
year = 2025
if year % 4 == 0 and year % 100 != 0 or year % 400 == 0:
    print ("leap year")
else:
    print ("not a leap year")
# Out:
# not a leap year

# %%
num = 44
if num > 0:
  print("positive")
elif num < 0:
  print("negative")
else:
  print("zero")
# Out:
# positive

# %%
a = 10
b = 20
c = 15
if (a > b and a > c):
  print(a,"is greatest")
elif (b > a and b > c):
  print(b,"is greatest")
elif (c > a and c > b):
  print(c,"is greatest")
else:
  print ("Values are equal")
# Out:
# 20 is greatest

# %%
# functions
#define function
def demoFunction():
    print ("This is a demo function")
#call the function
demoFunction()
# Out:
# This is a demo function

# %%
# function with arguments
def addFunction(a,b):
    print (a+b)

#call function with arguments
addFunction(10,20)
# Out:
# 30

# %%
#function with return type
def sumFunction(x,y):
    return x+y

#call the function
total = sumFunction(100,250)
print (total)
# Out:
# 350

# %%
def remFunction(x,y):
    return x%y

rem=remFunction(20,3)
print(rem)
# Out:
# 2

# %%
def remFunction(a):
  if a%2 == 0:
    return 'even'
  else:
    return 'odd'
#userinput
data = int(input("Enter a number "))
rem=remFunction(data)
print(rem)
# Out:
# Enter a number 23
# odd

# %%
def checkFunction(length):
  if(length%2==0):
    return 'even'
  else:
    return 'odd'

#userinput
name = input("Enter your name ");
length = len(name)
check = checkFunction(length)
print (length)
print (check)
# Out:
# Enter your name shubhechchha
# 12
# even

# %%
#loop/iteration

#for loop
# for i in range(10):
#   print (i)
#   print (i+1)

# for i in range(1,21,3):
#   print(i)

# for i in range(11):
#   print(i*10)

# for i in range(1,21):
#   if i%2 == 0:
#     print (i)

sum=0
for i in range(21):
  sum=sum+i
print(sum)
# Out:
# 210

# %%
num=4
for i in range(1,11):
  print(num,"*",i,"=",num*i)
# Out:
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40
